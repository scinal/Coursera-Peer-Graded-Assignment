# %% [markdown]
# # My Jupyter Notebook on IBM Watson Studio

# %% [markdown]
# <b> Sayeste Cagil Inal </b> <br> PhD Candidate

# %% [markdown]
# <i> I am interested in data science because it will add a lot to my research projects. It will also help with my upcoming fMRI studies. </i>

# %% [markdown]
# ### My code in the next line, cell five, will multiply 9 with 9.

# %%
9*9
# Out:
# 81

# %% [markdown]
# ---
# <a> https://www.youtube.com/watch?v=dQw4w9WgXcQ </a>
# <ol>
# <li>Never gonna give you up</li>
# <li>Never gonna let you down</li>
# <li>Never gonna run around and desert you</li>
# </ol>
# <strike>Sorry for the RickRolling!<strike>
